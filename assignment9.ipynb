# %% [markdown]
# (1) SparkSession의 객체 변수 spark를 만든다.
#
# (2) "PYSPARK_PYTHON" "PYSPARK_DRIVER_PYTHON" 환경변수를 출력
#
# (3) spark.version 출력
#
# (4) java, javac version 출력
#
# (5) 1,2,3,4,5,6,7 숫자를 RDD로 만들고, 앞부터 요소 3개를 출력한다.

# %%
#!pip install pyspark

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\rkdus3696\\miniconda\\python.exe'

# %%
import os, sys
import pyspark

os.environ["PYSPARK_PYTHON"]=sys.executable          # 현재 사용 중인 Python 실행 파일 경로 설정 (리눅스 "/usr/bin/python3")
os.environ["PYSPARK_DRIVER_PYTHON"]=sys.executable   # Driver에서도 동일한 Python 경로 설정

# %%
myConf=pyspark.SparkConf() # 기본 설정 객체 생성, 여기에 필요한 설정 정의

# %%
#(1)

# %%
spark = pyspark.sql.SparkSession\
    .builder\
    .master("local")\
    .appName("myApp")\
    .config(conf=myConf)\
    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       1 spark = pyspark.sql.SparkSession\
#       2     .builder\
#       3     .master("local")\
#       4     .appName("myApp")\
#       5     .config(conf=myConf)\
# ----> 6     .getOrCreate()
#
# File ~\miniconda\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# File ~\miniconda\Lib\site-packages\pyspark\context.py:515, in SparkContext.getOrCreate(cls, conf)
#     513 with SparkContext._lock:
#     514     if SparkContext._active_spark_context is None:
# ...

# %%
import sys
sys.version

# %%
sys.executable

# %%
#(2)

# %%
os.environ['PYSPARK_DRIVER_PYTHON']

# %%
os.environ['PYSPARK_PYTHON']

# %%
#(3)

# %%
spark.version

# %%
#(4)

# %%
# !java -version

# %%
# !javac -version

# %%
#(5)

# %%
myList=[1,2,3,4,5,6,7]

# %%
myRdd1 = spark.sparkContext.parallelize(myList)

# %%
myRdd1.take(3)

# %%
python -version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 python -version
#
# NameError: name 'python' is not defined
