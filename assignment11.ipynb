# %% [raw]
# 다음 데이터를 호선별로 집단화하여 승하차인원의 평균을 계산한다.
#
#
#
# _sub=["20150101,2호선,0236,영등포구청,6199,6219",
#
# "20150101,2호선,0237,당산,7982,8946",
#
# "20150101,2호선,0238,합정,17406,15241",
#
# "20150101,3호선,0309,지축,515,538",
#
# "20150101,3호선,0310,구파발,6879,6260",
#
# "20150101,3호선,0311,연신내,20031,19470",
#
# "20150101,3호선,0312,불광,9519,11029",
#
# "20150101,4호선,0425,회현,7465,7574",
#
# "20150101,4호선,0426,서울역,3943,10823",
#
# "20150101,경부선,1002,남영,4340,4535",
#
# "20150101,경부선,1003,용산,28980,27684",
#
# "20150101,경부선,1004,노량진,23021,23862",
#
# "20150101,경부선,1005,대방,6360,6476",
#
# "20150101,경부선,1006,영등포,37247,36102",
#
# "20150101,경원선,1008,이촌,1940,1507",
#
# "20150101,경원선,1009,서빙고,911,1000",
#
# "20150101,경원선,1010,한남,1885,1863",
#
# "20150101,경원선,1011,옥수,43,37"]
#
#
#
# (1) 승차인원의 평균을 계산하고 출력
#
#
#
# ```
#
# [('2호선', 10529.0),
#
#  ('3호선', 9236.0),
#
#  ('4호선', 5704.0),
#
#  ('경부선', 19989.6),
#
#  ('경원선', 1194.75)]
#
# ```
#
#
#
# (2) 하차인원의 평균을 계산하고 출력

# %%
import os, sys
import pyspark

os.environ["PYSPARK_PYTHON"]=sys.executable          # Worker가 사용할 Python 실행 파일 경로 설정 (리눅스 "/usr/bin/python3")
os.environ["PYSPARK_DRIVER_PYTHON"]=sys.executable   # Driver에서도 동일한 Python 경로 설정
# os.environ['HADOOP_HOME']=os.getcwd() # 현재 디렉터리를 HADOOP_HOME으로 설정
# os.environ["PATH"] += os.path.join(os.environ['HADOOP_HOME'], 'bin') # PATH에 Hadoop 바이너리 추가

myConf=pyspark.SparkConf() # 기본 설정 객체 생성, 여기에 필요한 설정 정의
# myConf=pyspark.SparkConf().set("spark.driver.bindAddress", "127.0.0.1") #드라이버 바인딩 주소 설정
# myConf=pyspark.SparkConf().set("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.13:10.1.1")

# %%
spark = pyspark.sql.SparkSession\
    .builder\
    .master("local")\
    .appName("test")\
    .config(conf=myConf)\
    .getOrCreate()

# %%
_sub=["20150101,2호선,0236,영등포구청,6199,6219",

"20150101,2호선,0237,당산,7982,8946",

"20150101,2호선,0238,합정,17406,15241",

"20150101,3호선,0309,지축,515,538",

"20150101,3호선,0310,구파발,6879,6260",

"20150101,3호선,0311,연신내,20031,19470",

"20150101,3호선,0312,불광,9519,11029",

"20150101,4호선,0425,회현,7465,7574",

"20150101,4호선,0426,서울역,3943,10823",

"20150101,경부선,1002,남영,4340,4535",

"20150101,경부선,1003,용산,28980,27684",

"20150101,경부선,1004,노량진,23021,23862",

"20150101,경부선,1005,대방,6360,6476",

"20150101,경부선,1006,영등포,37247,36102",

"20150101,경원선,1008,이촌,1940,1507",

"20150101,경원선,1009,서빙고,911,1000",

"20150101,경원선,1010,한남,1885,1863",

"20150101,경원선,1011,옥수,43,37"]

# %% [raw]
# #방법1)

# %%
_spark_sub=spark.sparkContext.parallelize(_sub)

# %%
split_sub = _spark_sub.map(lambda line: line.split(','))
split_sub.take(18)
# Out:
# [['20150101', '2호선', '0236', '영등포구청', '6199', '6219'],
#  ['20150101', '2호선', '0237', '당산', '7982', '8946'],
#  ['20150101', '2호선', '0238', '합정', '17406', '15241'],
#  ['20150101', '3호선', '0309', '지축', '515', '538'],
#  ['20150101', '3호선', '0310', '구파발', '6879', '6260'],
#  ['20150101', '3호선', '0311', '연신내', '20031', '19470'],
#  ['20150101', '3호선', '0312', '불광', '9519', '11029'],
#  ['20150101', '4호선', '0425', '회현', '7465', '7574'],
#  ['20150101', '4호선', '0426', '서울역', '3943', '10823'],
#  ['20150101', '경부선', '1002', '남영', '4340', '4535'],
#  ['20150101', '경부선', '1003', '용산', '28980', '27684'],
#  ['20150101', '경부선', '1004', '노량진', '23021', '23862'],
#  ['20150101', '경부선', '1005', '대방', '6360', '6476'],
#  ['20150101', '경부선', '1006', '영등포', '37247', '36102'],
#  ['20150101', '경원선', '1008', '이촌', '1940', '1507'],
#  ['20150101', '경원선', '1009', '서빙고', '911', '1000'],
#  ['20150101', '경원선', '1010', '한남', '1885', '1863'],
#  ['20150101', '경원선', '1011', '옥수', '43', '37']]

# %%
myRdd_group=split_sub.groupBy(lambda x:"2호선" in x)

for (k,v) in myRdd_group.collect():
    print ("{}: {}".format(k, v))
# Out:
# True: <pyspark.resultiterable.ResultIterable object at 0x00000281B38FEC40>
# False: <pyspark.resultiterable.ResultIterable object at 0x00000281B3A007F0>

# %%
for (k,v) in myRdd_group.collect():
    for eachValue in v:
        print ("{}: {}".format(k, eachValue))
        if k == True:
            line_num_2 = v
    print ("-----")
# Out:
# True: ['20150101', '2호선', '0236', '영등포구청', '6199', '6219']
# True: ['20150101', '2호선', '0237', '당산', '7982', '8946']
# True: ['20150101', '2호선', '0238', '합정', '17406', '15241']
# -----
# False: ['20150101', '3호선', '0309', '지축', '515', '538']
# False: ['20150101', '3호선', '0310', '구파발', '6879', '6260']
# False: ['20150101', '3호선', '0311', '연신내', '20031', '19470']
# False: ['20150101', '3호선', '0312', '불광', '9519', '11029']
# False: ['20150101', '4호선', '0425', '회현', '7465', '7574']
# False: ['20150101', '4호선', '0426', '서울역', '3943', '10823']
# False: ['20150101', '경부선', '1002', '남영', '4340', '4535']
# False: ['20150101', '경부선', '1003', '용산', '28980', '27684']
# False: ['20150101', '경부선', '1004', '노량진', '23021', '23862']
# False: ['20150101', '경부선', '1005', '대방', '6360', '6476']
# False: ['20150101', '경부선', '1006', '영등포', '37247', '36102']
# False: ['20150101', '경원선', '1008', '이촌', '1940', '1507']
# False: ['20150101', '경원선', '1009', '서빙고', '911', '1000']
# False: ['20150101', '경원선', '1010', '한남', '1885', '1863']
# False: ['20150101', '경원선', '1011', '옥수', '43', '37']
# -----

# %%
myRdd_group=split_sub.groupBy(lambda x:"3호선" in x)

for (k,v) in myRdd_group.collect():
    print ("{}: {}".format(k, v))

print ("\n")


for (k,v) in myRdd_group.collect():
    for eachValue in v:
        print ("{}: {}".format(k, eachValue))
        if k == True:
            line_num_3 = v
    print ("-----")
# Out:
# False: <pyspark.resultiterable.ResultIterable object at 0x00000281B34540D0>
# True: <pyspark.resultiterable.ResultIterable object at 0x00000281B3A18100>
#
#
# False: ['20150101', '2호선', '0236', '영등포구청', '6199', '6219']
# False: ['20150101', '2호선', '0237', '당산', '7982', '8946']
# False: ['20150101', '2호선', '0238', '합정', '17406', '15241']
# False: ['20150101', '4호선', '0425', '회현', '7465', '7574']
# False: ['20150101', '4호선', '0426', '서울역', '3943', '10823']
# False: ['20150101', '경부선', '1002', '남영', '4340', '4535']
# False: ['20150101', '경부선', '1003', '용산', '28980', '27684']
# False: ['20150101', '경부선', '1004', '노량진', '23021', '23862']
# False: ['20150101', '경부선', '1005', '대방', '6360', '6476']
# False: ['20150101', '경부선', '1006', '영등포', '37247', '36102']
# False: ['20150101', '경원선', '1008', '이촌', '1940', '1507']
# False: ['20150101', '경원선', '1009', '서빙고', '911', '1000']
# False: ['20150101', '경원선', '1010', '한남', '1885', '1863']
# False: ['20150101', '경원선', '1011', '옥수', '43', '37']
# -----
# True: ['20150101', '3호선', '0309', '지축', '515', '538']
# True: ['20150101', '3호선', '0310', '구파발', '6879', '6260']
# True: ['20150101', '3호선', '0311', '연신내', '20031', '19470']
# True: ['20150101', '3호선', '0312', '불광', '9519', '11029']
# -----

# %%
myRdd_group=split_sub.groupBy(lambda x:"4호선" in x)

for (k,v) in myRdd_group.collect():
    print ("{}: {}".format(k, v))

print ("\n")


for (k,v) in myRdd_group.collect():
    for eachValue in v:
        print ("{}: {}".format(k, eachValue))
        if k == True:
            line_num_4 = v
    print ("-----")
# Out:
# False: <pyspark.resultiterable.ResultIterable object at 0x00000281B38FEBE0>
# True: <pyspark.resultiterable.ResultIterable object at 0x00000281B3A11E80>
#
#
# False: ['20150101', '2호선', '0236', '영등포구청', '6199', '6219']
# False: ['20150101', '2호선', '0237', '당산', '7982', '8946']
# False: ['20150101', '2호선', '0238', '합정', '17406', '15241']
# False: ['20150101', '3호선', '0309', '지축', '515', '538']
# False: ['20150101', '3호선', '0310', '구파발', '6879', '6260']
# False: ['20150101', '3호선', '0311', '연신내', '20031', '19470']
# False: ['20150101', '3호선', '0312', '불광', '9519', '11029']
# False: ['20150101', '경부선', '1002', '남영', '4340', '4535']
# False: ['20150101', '경부선', '1003', '용산', '28980', '27684']
# False: ['20150101', '경부선', '1004', '노량진', '23021', '23862']
# False: ['20150101', '경부선', '1005', '대방', '6360', '6476']
# False: ['20150101', '경부선', '1006', '영등포', '37247', '36102']
# False: ['20150101', '경원선', '1008', '이촌', '1940', '1507']
# False: ['20150101', '경원선', '1009', '서빙고', '911', '1000']
# False: ['20150101', '경원선', '1010', '한남', '1885', '1863']
# False: ['20150101', '경원선', '1011', '옥수', '43', '37']
# -----
# True: ['20150101', '4호선', '0425', '회현', '7465', '7574']
# True: ['20150101', '4호선', '0426', '서울역', '3943', '10823']
# -----

# %%
myRdd_group=split_sub.groupBy(lambda x:"경부선" in x)

for (k,v) in myRdd_group.collect():
    print ("{}: {}".format(k, v))

print ("\n")


for (k,v) in myRdd_group.collect():
    for eachValue in v:
        print ("{}: {}".format(k, eachValue))
        if k == True:
            line_경부선 = v
    print ("-----")
# Out:
# False: <pyspark.resultiterable.ResultIterable object at 0x00000281B38D06D0>
# True: <pyspark.resultiterable.ResultIterable object at 0x00000281B3A1E610>
#
#
# False: ['20150101', '2호선', '0236', '영등포구청', '6199', '6219']
# False: ['20150101', '2호선', '0237', '당산', '7982', '8946']
# False: ['20150101', '2호선', '0238', '합정', '17406', '15241']
# False: ['20150101', '3호선', '0309', '지축', '515', '538']
# False: ['20150101', '3호선', '0310', '구파발', '6879', '6260']
# False: ['20150101', '3호선', '0311', '연신내', '20031', '19470']
# False: ['20150101', '3호선', '0312', '불광', '9519', '11029']
# False: ['20150101', '4호선', '0425', '회현', '7465', '7574']
# False: ['20150101', '4호선', '0426', '서울역', '3943', '10823']
# False: ['20150101', '경원선', '1008', '이촌', '1940', '1507']
# False: ['20150101', '경원선', '1009', '서빙고', '911', '1000']
# False: ['20150101', '경원선', '1010', '한남', '1885', '1863']
# False: ['20150101', '경원선', '1011', '옥수', '43', '37']
# -----
# True: ['20150101', '경부선', '1002', '남영', '4340', '4535']
# True: ['20150101', '경부선', '1003', '용산', '28980', '27684']
# True: ['20150101', '경부선', '1004', '노량진', '23021', '23862']
# True: ['20150101', '경부선', '1005', '대방', '6360', '6476']
# True: ['20150101', '경부선', '1006', '영등포', '37247', '36102']
# -----

# %%
myRdd_group=split_sub.groupBy(lambda x:"경원선" in x)

for (k,v) in myRdd_group.collect():
    print ("{}: {}".format(k, v))

print ("\n")


for (k,v) in myRdd_group.collect():
    for eachValue in v:
        print ("{}: {}".format(k, eachValue))
        if k == True:
            line_경원선 = v
    print ("-----")
# Out:
# False: <pyspark.resultiterable.ResultIterable object at 0x00000281B38E1E50>
# True: <pyspark.resultiterable.ResultIterable object at 0x00000281B38FECA0>
#
#
# False: ['20150101', '2호선', '0236', '영등포구청', '6199', '6219']
# False: ['20150101', '2호선', '0237', '당산', '7982', '8946']
# False: ['20150101', '2호선', '0238', '합정', '17406', '15241']
# False: ['20150101', '3호선', '0309', '지축', '515', '538']
# False: ['20150101', '3호선', '0310', '구파발', '6879', '6260']
# False: ['20150101', '3호선', '0311', '연신내', '20031', '19470']
# False: ['20150101', '3호선', '0312', '불광', '9519', '11029']
# False: ['20150101', '4호선', '0425', '회현', '7465', '7574']
# False: ['20150101', '4호선', '0426', '서울역', '3943', '10823']
# False: ['20150101', '경부선', '1002', '남영', '4340', '4535']
# False: ['20150101', '경부선', '1003', '용산', '28980', '27684']
# False: ['20150101', '경부선', '1004', '노량진', '23021', '23862']
# False: ['20150101', '경부선', '1005', '대방', '6360', '6476']
# False: ['20150101', '경부선', '1006', '영등포', '37247', '36102']
# -----
# True: ['20150101', '경원선', '1008', '이촌', '1940', '1507']
# True: ['20150101', '경원선', '1009', '서빙고', '911', '1000']
# True: ['20150101', '경원선', '1010', '한남', '1885', '1863']
# True: ['20150101', '경원선', '1011', '옥수', '43', '37']
# -----

# %%
for i in line_num_2:
    print(i)

print ("\n")

for i in line_num_3:
    print(i)

print ("\n")

for i in line_num_4:
    print(i)

print ("\n")

for i in line_경부선:
    print(i)

print ("\n")

for i in line_경원선:
    print(i)
# Out:
# ['20150101', '2호선', '0236', '영등포구청', '6199', '6219']
# ['20150101', '2호선', '0237', '당산', '7982', '8946']
# ['20150101', '2호선', '0238', '합정', '17406', '15241']
#
#
# ['20150101', '3호선', '0309', '지축', '515', '538']
# ['20150101', '3호선', '0310', '구파발', '6879', '6260']
# ['20150101', '3호선', '0311', '연신내', '20031', '19470']
# ['20150101', '3호선', '0312', '불광', '9519', '11029']
#
#
# ['20150101', '4호선', '0425', '회현', '7465', '7574']
# ['20150101', '4호선', '0426', '서울역', '3943', '10823']
#
#
# ['20150101', '경부선', '1002', '남영', '4340', '4535']
# ['20150101', '경부선', '1003', '용산', '28980', '27684']
# ['20150101', '경부선', '1004', '노량진', '23021', '23862']
# ['20150101', '경부선', '1005', '대방', '6360', '6476']
# ['20150101', '경부선', '1006', '영등포', '37247', '36102']
#
#
# ['20150101', '경원선', '1008', '이촌', '1940', '1507']
# ['20150101', '경원선', '1009', '서빙고', '911', '1000']
# ['20150101', '경원선', '1010', '한남', '1885', '1863']
# ['20150101', '경원선', '1011', '옥수', '43', '37']

# %%
sol_2 = 0
sol_3 = 0
sol_4 = 0
sol_경부선 = 0
sol_경원선 = 0

for i in line_num_2:
    #print(i[4])
    sol_2 = sol_2 + int(i[4])
print(sol_2)

print ("\n")

for i in line_num_3:
    #print(i[4])
    sol_3 = sol_3 + int(i[4])
print(sol_3)

print ("\n")

for i in line_num_4:
    #print(i[4)
    sol_4 = sol_4 + int(i[4])
print(sol_4)

print ("\n")

for i in line_경부선:
    #print(i[4])
    sol_경원선 = sol_경원선 + int(i[4])
print(sol_경원선)

print ("\n")

for i in line_경원선:
    #print(i[4])
    sol_경부선 = sol_경부선 + int(i[4])
print(sol_경부선)
# Out:
# 31587
#
#
# 36944
#
#
# 11408
#
#
# 99948
#
#
# 4779

# %% [raw]
# sum_counts = _subLineByPassengers.combineByKey(
#     (lambda x: (x, 1)), # the initial value, with value x and count 1
#     (lambda acc, value: (acc[0]+value, acc[1]+1)), # how to combine a pair value with the accumulator: sum value, and increment count
#     (lambda acc1, acc2: (acc1[0]+acc2[0], acc1[1]+acc2[1])) # combine accumulators
# )

# %%
sol_2 = 0
sol_3 = 0
sol_4 = 0
sol_경부선 = 0
sol_경원선 = 0

j=0

for i in line_num_2:
    #print(i[5])
    sol_2 = sol_2 + int(i[5])
print(sol_2/len(line_num_2))

print ("\n")

for i in line_num_3:
    #print(i[5])
    sol_3 = sol_3 + int(i[5])
print(sol_3/len(line_num_3))

print ("\n")

for i in line_num_4:
    #print(i[5))
    sol_4 = sol_4 + int(i[5])
print(sol_4/len(line_num_4))

print ("\n")

for i in line_경부선:
    #print(i[5])
    sol_경원선 = sol_경원선 + int(i[5])
print(sol_경원선/len(line_경원선))

print ("\n")

for i in line_경원선:
    #print(i[5])
    sol_경부선 = sol_경부선 + int(i[5])
print(sol_경부선/len(line_경부선))
# Out:
# 10135.333333333334
#
#
# 9324.25
#
#
# 9198.5
#
#
# 24664.75
#
#
# 881.4

# %% [raw]
# #방법2)

# %%
_subRdd = spark.sparkContext.parallelize(_sub)

# %%
_subRdd.map(lambda x:x.split(',')).map(lambda x:int(x[4])).collect()
# Out:
# [6199,
#  7982,
#  17406,
#  515,
#  6879,
#  20031,
#  9519,
#  7465,
#  3943,
#  4340,
#  28980,
#  23021,
#  6360,
#  37247,
#  1940,
#  911,
#  1885,
#  43]

# %%
_subLineByPassengers=_subRdd.map(lambda x:x.split(',')).map(lambda x: (x[1],int(x[4])))
sum_counts = _subLineByPassengers.combineByKey(
    (lambda x: (x, 1)), # the initial value, with value x and count 1
    (lambda acc, value: (acc[0]+value, acc[1]+1)), # how to combine a pair value with the accumulator: sum value, and increment count
    (lambda acc1, acc2: (acc1[0]+acc2[0], acc1[1]+acc2[1])) # combine accumulators
)

# %%
for i in sum_counts.collect():
    for each in i:
        print (each, end=" ")
    print()
# Out:
# 2호선 (31587, 3)
# 3호선 (36944, 4)
# 4호선 (11408, 2)
# 경부선 (99948, 5)
# 경원선 (4779, 4)

# %%
averageByKey = sum_counts.map(lambda x: (x[0],x[1][0]/x[1][1]))

# %%
averageByKey.collect()
# Out:
# [('2호선', 10529.0),
#  ('3호선', 9236.0),
#  ('4호선', 5704.0),
#  ('경부선', 19989.6),
#  ('경원선', 1194.75)]

# %%
_subRdd.map(lambda x:x.split(',')).map(lambda x:int(x[5])).collect()
# Out:
# [6219,
#  8946,
#  15241,
#  538,
#  6260,
#  19470,
#  11029,
#  7574,
#  10823,
#  4535,
#  27684,
#  23862,
#  6476,
#  36102,
#  1507,
#  1000,
#  1863,
#  37]

# %%
_subLineByPassengers=_subRdd.map(lambda x:x.split(',')).map(lambda x: (x[1],int(x[5])))
sum_counts = _subLineByPassengers.combineByKey(
    (lambda x: (x, 1)), # the initial value, with value x and count 1
    (lambda acc, value: (acc[0]+value, acc[1]+1)), # how to combine a pair value with the accumulator: sum value, and increment count
    (lambda acc1, acc2: (acc1[0]+acc2[0], acc1[1]+acc2[1])) # combine accumulators
)

# %%
for i in sum_counts.collect():
    for each in i:
        print (each, end=" ")
    print()
# Out:
# 2호선 (30406, 3)
# 3호선 (37297, 4)
# 4호선 (18397, 2)
# 경부선 (98659, 5)
# 경원선 (4407, 4)

# %%
averageByKey = sum_counts.map(lambda x: (x[0],x[1][0]/x[1][1]))

# %%
averageByKey.collect()
# Out:
# [('2호선', 10135.333333333334),
#  ('3호선', 9324.25),
#  ('4호선', 9198.5),
#  ('경부선', 19731.8),
#  ('경원선', 1101.75)]
